# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\gauri\\ML python P308'

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
pwd
# Out:
# 'C:\\Users\\gauri\\ML python P308'

# %%
# check data file is available
print(os.path.isfile("Automobile_data.csv"))
# Out:
# True

# %%
df=pd.read_csv("Automobile_data.csv")

# %%
# see top 5 rows
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
df.shape
# Out:
# (205, 26)

# %%
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)

# %%
#  columns and types
print(df.columns)
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
#data types of col
print(df.dtypes)
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
# no of col datatypes and null/not
# in numerical values datatype has weired values or text values, object then it consisder as noisy data, null values 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
#duplicate of data
mydata=df.copy()

# %%
mydata
# Out:
#      symboling normalized-losses           make fuel-type aspiration  \
# 0            3                 ?    alfa-romero       gas        std
# 1            3                 ?    alfa-romero       gas        std
# 2            1                 ?    alfa-romero       gas        std
# 3            2               164           audi       gas        std
# 4            2               164           audi       gas        std
# 5            2                 ?           audi       gas        std
# 6            1               158           audi       gas        std
# 7            1                 ?           audi       gas        std
# 8            1               158           audi       gas      turbo
# 9            0                 ?           audi       gas      turbo
# 10           2               192            bmw       gas        std
# 11           0               192            bmw       gas        std
# 12           0               188            bmw       gas        std
# ...

# %%
# find null value
#print(df.isna().sum())
#print(df.isna())
#print(df.isnull().any())
# print(df.info())
mydata.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
df_num=mydata.select_dtypes(include='number')
df_num.head()
# Out:
#    symboling  wheel-base  length  width  height  curb-weight  engine-size  \
# 0          3        88.6   168.8   64.1    48.8         2548          130
# 1          3        88.6   168.8   64.1    48.8         2548          130
# 2          1        94.5   171.2   65.5    52.4         2823          152
# 3          2        99.8   176.6   66.2    54.3         2337          109
# 4          2        99.4   176.6   66.4    54.3         2824          136
#
#    compression-ratio  city-mpg  highway-mpg
# 0                9.0        21           27
# 1                9.0        21           27
# 2                9.0        19           26
# 3               10.0        24           30
# 4                8.0        18           22

# %%
df_cat=mydata.select_dtypes(include='object')
df_cat.head()
# Out:
#   normalized-losses         make fuel-type aspiration num-of-doors  \
# 0                 ?  alfa-romero       gas        std          two
# 1                 ?  alfa-romero       gas        std          two
# 2                 ?  alfa-romero       gas        std          two
# 3               164         audi       gas        std         four
# 4               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location engine-type num-of-cylinders  \
# 0  convertible          rwd           front        dohc             four
# 1  convertible          rwd           front        dohc             four
# 2    hatchback          rwd           front        ohcv              six
# 3        sedan          fwd           front         ohc             four
# 4        sedan          4wd           front         ohc             five
#
#   fuel-system  bore stroke horsepower peak-rpm  price
# 0        mpfi  3.47   2.68        111     5000  13495
# ...

# %%
for i in df_cat.columns:
    print(i,df_cat[i].unique())
    print('')
# Out:
# normalized-losses ['?' '164' '158' '192' '188' '121' '98' '81' '118' '148' '110' '145' '137'
#  '101' '78' '106' '85' '107' '104' '113' '150' '129' '115' '93' '142'
#  '161' '153' '125' '128' '122' '103' '168' '108' '194' '231' '119' '154'
#  '74' '186' '83' '102' '89' '87' '77' '91' '134' '65' '197' '90' '94'
#  '256' '95']
#
# make ['alfa-romero' 'audi' 'bmw' 'chevrolet' 'dodge' 'honda' 'isuzu' 'jaguar'
#  'mazda' 'mercedes-benz' 'mercury' 'mitsubishi' 'nissan' 'peugot'
#  'plymouth' 'porsche' 'renault' 'saab' 'subaru' 'toyota' 'volkswagen'
#  'volvo']
#
# fuel-type ['gas' 'diesel']
#
# aspiration ['std' 'turbo']
#
# num-of-doors ['two' 'four' '?']
#
# body-style ['convertible' 'hatchback' 'sedan' 'wagon' 'hardtop']
#
# drive-wheels ['rwd' 'fwd' '4wd']
#
# engine-location ['front' 'rear']
#
# engine-type ['dohc' 'ohcv' 'ohc' 'l' 'rotor' 'ohcf' 'dohcv']
#
# num-of-cylinders ['four' 'six' 'five' 'three' 'twelve' 'two' 'eight']
#
# ...

# %%
# to check outliers/ missing value in all columns
unique_values_count = df.apply(pd.Series.nunique)
print(unique_values_count)
# Out:
# symboling              6
# normalized-losses     52
# make                  22
# fuel-type              2
# aspiration             2
# num-of-doors           3
# body-style             5
# drive-wheels           3
# engine-location        2
# wheel-base            53
# length                75
# width                 44
# height                49
# curb-weight          171
# engine-type            7
# num-of-cylinders       7
# engine-size           44
# fuel-system            8
# bore                  39
# stroke                37
# compression-ratio     32
# horsepower            60
# peak-rpm              24
# city-mpg              29
# highway-mpg           30
# price                187
# dtype: int64

# %%
for i in df_num.columns:
    print(i,df_num[i].unique())
    print('')
# Out:
# symboling [ 3  1  2  0 -1 -2]
#
# wheel-base [ 88.6  94.5  99.8  99.4 105.8  99.5 101.2 103.5 110.   88.4  93.7 103.3
#   95.9  86.6  96.5  94.3  96.  113.  102.   93.1  95.3  98.8 104.9 106.7
#  115.6  96.6 120.9 112.  102.7  93.   96.3  95.1  97.2 100.4  91.3  99.2
#  107.9 114.2 108.   89.5  98.4  96.1  99.1  93.3  97.   96.9  95.7 102.4
#  102.9 104.5  97.3 104.3 109.1]
#
# length [168.8 171.2 176.6 177.3 192.7 178.2 176.8 189.  193.8 197.  141.1 155.9
#  158.8 157.3 174.6 173.2 144.6 150.  163.4 157.1 167.5 175.4 169.1 170.7
#  172.6 199.6 191.7 159.1 166.8 169.  177.8 175.  190.9 187.5 202.6 180.3
#  208.1 199.2 178.4 173.  172.4 165.3 170.2 165.6 162.4 173.4 181.7 184.6
#  178.5 186.7 198.9 167.3 168.9 175.7 181.5 186.6 156.9 157.9 172.  173.5
#  173.6 158.7 169.7 166.3 168.7 176.2 175.6 183.5 187.8 171.7 159.3 165.7
#  180.2 183.1 188.8]
#
# width [64.1 65.5 66.2 66.4 66.3 71.4 67.9 64.8 66.9 70.9 60.3 63.6 63.8 64.6
# ...

# %%
mydata.replace('?',np.nan,inplace=True)

# %%
mydata.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
#converting to number dtype

# %%
mydata['normalized-losses']=mydata['normalized-losses'].astype('float64')
mydata['horsepower']=mydata['horsepower'].astype('float64')
mydata['peak-rpm']=mydata['peak-rpm'].astype('float64')
mydata['price']=mydata['price'].astype('float64')
mydata['bore']=mydata['bore'].astype('float64')
mydata['stroke']=mydata['stroke'].astype('float64')

# %%
mydata.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
#treating the missing values
lst=['normalized-losses','bore','stroke','horsepower','peak-rpm','price']

# %%
for i in lst:
    mean=np.mean(mydata[i])
    print(mean)

#for i in lst:
#    med=np.median(mydata[i])
# print(med)
# Out:
# 122.0
# 3.3297512437810943
# 3.255422885572139
# 104.25615763546799
# 5125.369458128079
# 13207.129353233831

# %%
for i in lst:
    mydata[i]=mydata[i].fillna(mydata[i].median())

# %%
mydata.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         2
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
mydata['num-of-doors'].mode()
# Out:
# 0    four
# Name: num-of-doors, dtype: object

# %%
mydata['num-of-doors']=mydata['num-of-doors'].fillna('four')

# %%
mydata.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
#outlier
df_num.plot(kind='box',subplots=True,layout=(4,4),figsize=(10,10))
# Out:
# symboling               Axes(0.125,0.712609;0.168478x0.167391)
# wheel-base           Axes(0.327174,0.712609;0.168478x0.167391)
# length               Axes(0.529348,0.712609;0.168478x0.167391)
# width                Axes(0.731522,0.712609;0.168478x0.167391)
# height                  Axes(0.125,0.511739;0.168478x0.167391)
# curb-weight          Axes(0.327174,0.511739;0.168478x0.167391)
# engine-size          Axes(0.529348,0.511739;0.168478x0.167391)
# compression-ratio    Axes(0.731522,0.511739;0.168478x0.167391)
# city-mpg                 Axes(0.125,0.31087;0.168478x0.167391)
# highway-mpg           Axes(0.327174,0.31087;0.168478x0.167391)
# dtype: object

# %%
#import searborn as sns
plt.figure()
sns.boxplot(mydata['price'])
# Out:
# <Axes: ylabel='price'>

# %%
#import searborn as sns
plt.figure()
sns.boxplot(data=mydata,x='price',y='make')
# Out:
# <Axes: xlabel='price', ylabel='make'>

# %%
mydata[(mydata['price']>10000) & (mydata['make']=='dodge')]
# Out:
#     symboling  normalized-losses   make fuel-type aspiration num-of-doors  \
# 29          3              145.0  dodge       gas      turbo          two
#
#    body-style drive-wheels engine-location  wheel-base  length  width  height  \
# 29  hatchback          fwd           front        95.9   173.2   66.3    50.2
#
#     curb-weight engine-type num-of-cylinders  engine-size fuel-system  bore  \
# 29         2811         ohc             four          156         mfi   3.6
#
#     stroke  compression-ratio  horsepower  peak-rpm  city-mpg  highway-mpg  \
# 29     3.9                7.0       145.0    5000.0        19           24
#
#       price
# 29  12964.0

# %%
for i in mydata['make'].unique():     #for  loop company wise
    price=mydata[mydata['make']==i]['price']
    q1=np.quantile(price,0.25)
    q3=np.quantile(price,0.75)
    IQR=q3-q1
    #print(IQR)
    ub=q3+1.5*IQR
    index=price[price>ub].index
    print(index)
    if len(index)!=0:
        mydata.drop(index,inplace=True)
# Out:
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([29], dtype='int64')
# Index([41], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([83, 84], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([124], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([172, 178, 179, 180, 181], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')

# %%
plt.figure()
sns.boxplot(data=mydata,x='price',y='make')
# Out:
# <Axes: xlabel='price', ylabel='make'>

# %%
for i in mydata['make'].unique():
    price=mydata[mydata['make']==i]['price']
    q1=np.quantile(price,0.25)
    q3=np.quantile(price,0.75)
    IQR=q3-q1
    #print(IQR)
    ub=q3+1.5*IQR
    lb=q1-1.5*IQR
    index=price[price>ub].index
    index2=price[price<lb].index
    print(index)
    if len(index)!=0:
        mydata.drop(index,inplace=True)
    if len(index2)!=0:
        mydata.drop(index2,inplace=True)
# Out:
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')

# %%
#import searborn as sns
plt.figure()
sns.boxplot(data=mydata,x='price',y='make')
# Out:
# <Axes: xlabel='price', ylabel='make'>

# %%
df_num.plot(kind='box',subplots=True,layout=(4,4),figsize=(10,10))
# Out:
# symboling               Axes(0.125,0.712609;0.168478x0.167391)
# wheel-base           Axes(0.327174,0.712609;0.168478x0.167391)
# length               Axes(0.529348,0.712609;0.168478x0.167391)
# width                Axes(0.731522,0.712609;0.168478x0.167391)
# height                  Axes(0.125,0.511739;0.168478x0.167391)
# curb-weight          Axes(0.327174,0.511739;0.168478x0.167391)
# engine-size          Axes(0.529348,0.511739;0.168478x0.167391)
# compression-ratio    Axes(0.731522,0.511739;0.168478x0.167391)
# city-mpg                 Axes(0.125,0.31087;0.168478x0.167391)
# highway-mpg           Axes(0.327174,0.31087;0.168478x0.167391)
# dtype: object

# %%
# outliers
#import searborn as sns
plt.figure()
sns.boxplot(mydata['wheel-base'])
# Out:
# <Axes: ylabel='wheel-base'>

# %%
plt.figure()
sns.boxplot(data=mydata,x='wheel-base',y='make')
# Out:
# <Axes: xlabel='wheel-base', ylabel='make'>

# %%
for i in mydata['make'].unique():
    wheelbase=mydata[mydata['make']==i]['wheel-base']
    q1=np.quantile(wheelbase,0.25)
    q3=np.quantile(wheelbase,0.75)
    IQR=q3-q1
    #print(IQR)
    ub=q3+1.5*IQR
    lb=q1-1.5*IQR
    index=wheelbase[wheelbase>ub].index
    index2=wheelbase[wheelbase<lb].index
    print(index)
    if len(index)!=0:
        mydata.drop(index,inplace=True)
    if len(index2)!=0:
        mydata.drop(index2,inplace=True)
# Out:
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([17], dtype='int64')
# Index([], dtype='int64')
# Index([28], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([123], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([], dtype='int64')
# Index([191, 192, 193], dtype='int64')
# Index([], dtype='int64')

# %%
plt.figure()
sns.boxplot(data=mydata,x='wheel-base',y='make')
# Out:
# <Axes: xlabel='wheel-base', ylabel='make'>

# %%
df_num=mydata.select_dtypes(include='number')
df_cat=mydata.select_dtypes(include='object')

# %%
df_num.columns
# Out:
# Index(['symboling', 'normalized-losses', 'wheel-base', 'length', 'width',
#        'height', 'curb-weight', 'engine-size', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
df_cat.columns
# Out:
# Index(['make', 'fuel-type', 'aspiration', 'num-of-doors', 'body-style',
#        'drive-wheels', 'engine-location', 'engine-type', 'num-of-cylinders',
#        'fuel-system'],
#       dtype='object')

# %%
# to handle sckeweness we can use srt or log transformation 
from scipy.stats import skew
print(skew(df_num['wheel-base']))
print(skew(df_num['horsepower']))
print(skew(df_num['price']))
print(skew(df_num['compression-ratio']))
# Out:
# 1.1372456341853063
# 1.5505113007971427
# 1.8192238542042534
# 2.4693579730740174

# %%
for i in df_num.columns:
    plt.figure()
    sns.displot(df_num[i],kind='kde')
    plt.show()
    print(skew(df_num[i]))
# Out:
# 0.23446770399368058
# 0.7003331030543607
# 1.1372456341853063
# 0.276662717365823
# 0.9301530204532297
# -0.051793850290272656
# 0.750530918717122
# 2.0700486203120514
# 0.05721140344761004
# -0.6893111255969832
# 2.4693579730740174
# 1.5505113007971427
# 0.04511994458622002
# 0.4618359163504056
# 0.37866199510664533
# 1.8192238542042534

# %%
# to find all the columns has skewness <1 and >-1
lst=[]
for i in df_num.columns:
    if skew(df_num[i])>1 or skew(df_num[i])<-1:
        lst.append(i)
print(lst)
# Out:
# ['wheel-base', 'engine-size', 'compression-ratio', 'horsepower', 'price']

# %%
for i in lst:
    df_num[i]=np.log(df_num[i])

# %%
for i in df_num.columns:
    plt.figure()
    sns.displot(df_num[i],kind='kde')
    plt.show()
    print(skew(df_num[i]))
# Out:
# 0.23446770399368058
# 0.7003331030543607
# 0.9922196889528089
# 0.276662717365823
# 0.9301530204532297
# -0.051793850290272656
# 0.750530918717122
# 0.9317054789375602
# 0.05721140344761004
# -0.6893111255969832
# 2.2572809515373975
# 0.5494759954982105
# 0.04511994458622002
# 0.4618359163504056
# 0.37866199510664533
# 0.7258810227321152

# %%
# Scaling
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_scaled=sc.fit_transform(df_num)
x_scaled
# Out:
# array([[ 1.9150576 , -0.16856139, -1.81299212, ..., -0.68576274,
#         -0.59468974,  0.33928221],
#        [ 1.9150576 , -0.16856139, -1.81299212, ..., -0.68576274,
#         -0.59468974,  0.74157402],
#        [ 0.20857063, -0.16856139, -0.73141678, ..., -0.99551756,
#         -0.74213348,  0.74157402],
#        ...,
#        [-1.49791634, -0.82814946,  1.67884321, ..., -1.15039497,
#         -1.18446469,  1.26983846],
#        [-1.49791634, -0.82814946,  1.67884321, ...,  0.08862429,
#         -0.59468974,  1.35953732],
#        [-1.49791634, -0.82814946,  1.67884321, ..., -0.99551756,
#         -0.88957721,  1.37329329]])

# %%
from sklearn.preprocessing import MinMaxScaler
sc=MinMaxScaler()
x_scaled=sc.fit_transform(df_num)
x_scaled
# Out:
# array([[1.        , 0.30120482, 0.00721797, ..., 0.23529412, 0.2972973 ,
#         0.44254881],
#        [1.        , 0.30120482, 0.00721797, ..., 0.23529412, 0.2972973 ,
#         0.5349254 ],
#        [0.6       , 0.30120482, 0.21312557, ..., 0.17647059, 0.27027027,
#         0.5349254 ],
#        ...,
#        [0.2       , 0.18072289, 0.6719848 , ..., 0.14705882, 0.18918919,
#         0.65622856],
#        [0.2       , 0.18072289, 0.6719848 , ..., 0.38235294, 0.2972973 ,
#         0.67682573],
#        [0.2       , 0.18072289, 0.6719848 , ..., 0.17647059, 0.24324324,
#         0.67998446]])

# %%
pip install seaborn --upgrade
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    - -------------------------------------- 10.2/294.9 kB ? eta -:--:--
#    ---- ---------------------------------- 30.7/294.9 kB 445.2 kB/s eta 0:00:01
#    ------------ -------------------------- 92.2/294.9 kB 751.6 kB/s eta 0:00:01
#    -------------------------- ------------- 194.6/294.9 kB 1.3 MB/s eta 0:00:01
#    ------------------------------- -------- 235.5/294.9 kB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 294.9/294.9 kB 1.3 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df_cat.head()
# Out:
#           make fuel-type aspiration num-of-doors   body-style drive-wheels  \
# 0  alfa-romero       gas        std          two  convertible          rwd
# 1  alfa-romero       gas        std          two  convertible          rwd
# 2  alfa-romero       gas        std          two    hatchback          rwd
# 3         audi       gas        std         four        sedan          fwd
# 4         audi       gas        std         four        sedan          4wd
#
#   engine-location engine-type num-of-cylinders fuel-system
# 0           front        dohc             four        mpfi
# 1           front        dohc             four        mpfi
# 2           front        ohcv              six        mpfi
# 3           front         ohc             four        mpfi
# 4           front         ohc             five        mpfi

# %%
for i in df_cat.columns:
    plt.figure()
    sns.catplot(df_cat[i],kind='count',palette='Paired')
    plt.show()

# %%
sns.__version__
# Out:
# '0.12.2'

# %%
#label encoder
from sklearn.preprocessing import LabelEncoder
for i in df_cat:
    le=LabelEncoder()
    df_cat[i]=le.fit_transform(df_cat[i])

# %%
df_cat.head()
# Out:
#    make  fuel-type  aspiration  num-of-doors  body-style  drive-wheels  \
# 0     0          1           0             1           0             2
# 1     0          1           0             1           0             2
# 2     0          1           0             1           2             2
# 3     1          1           0             0           3             1
# 4     1          1           0             0           3             0
#
#    engine-location  engine-type  num-of-cylinders  fuel-system
# 0                0            0                 2            4
# 1                0            0                 2            4
# 2                0            5                 3            4
# 3                0            3                 2            4
# 4                0            3                 1            4

# %%
# pandas profiling library is used to EDA of data 
# !pip install ydata-profiling
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 0.0/107.3 kB ? eta -:--:--
#      ---------------------------------------- 0.0/107.3 kB ? eta -:--:--
#      ---------------------------------------- 0.0/107.3 kB ? eta -:--:--
#      ---------------------------------------- 0.0/107.3 kB ? eta -:--:--
#      ----------- --------------------------- 30.7/107.3 kB 1.4 MB/s eta 0:00:01
#      ----------- --------------------------- 30.7/107.3 kB 1.4 MB/s eta 0:00:01
#      ----------- --------------------------- 30.7/107.3 kB 1.4 MB/s eta 0:00:01
#      ----------- --------------------------- 30.7/107.3 kB 1.4 MB/s eta 0:00:01
#      ----------- --------------------------- 30.7/107.3 kB 1.4 MB/s eta 0:00:01
#      ----------- --------------------------- 30.7/107.3 kB 1.4 MB/s eta 0:00:01
#      ----------- --------------------------- 30.7/107.3 kB 1.4 MB/s eta 0:00:01
# ...

# %%
from ydata_profiling import ProfileReport
report=ProfileReport(mydata)
report.to_file(output_file='oput.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
from ydata_profiling import ProfileReport
report=ProfileReport(df)
report.to_file(output_file='output.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
